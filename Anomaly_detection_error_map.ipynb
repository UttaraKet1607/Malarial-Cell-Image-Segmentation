# %% [markdown]
# <a href="https://colab.research.google.com/github/UttaraKet1607/Malarial-Cell-Image-Segmentation/blob/main/Anomaly_training_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Resources
# 1. https://github.com/bnsreenu/python_for_microscopists/blob/master/260_image_anomaly_detection_using_autoencoders/260_image_anomaly_detection_using_autoencoders.py
# 2. https://www.youtube.com/watch?v=q_tpFGHiRgg
# 3. https://github.com/mayur7garg/MalariaCellImageClassification

# %% [markdown]
# ### Implementation

# %%
! pip install kaggle
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets download iarunava/cell-images-for-detecting-malaria
! unzip cell-images-for-detecting-malaria.zip

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf

from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
import os
os.mkdir('/content/cell_images/Train_Uninfected')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-41-0b814e3a29f2> in <module>()
#       1 import os
# ----> 2 os.mkdir('/content/cell_images/Train_Uninfected')
#
# FileExistsError: [Errno 17] File exists: '/content/cell_images/Train_Uninfected'

# %%
import shutil

# absolute path
src_path = "/content/cell_images/Uninfected"
dst_path = "/content/cell_images/Train_Uninfected"
shutil.move(src_path, dst_path)

# %%
os.mkdir('/content/cell_images/Test_Parasitized')

# %%
# absolute path
src_path = "/content/cell_images/Parasitized"
dst_path = "/content/cell_images/Test_Parasitized"
shutil.move(src_path, dst_path)

# %%
#Size of our input images
Size = 128

#Define generators for training, validation and also anomaly data.

batch_size = 64
datagen_train = ImageDataGenerator(rescale=1./255, validation_split=0.3)
datagen = ImageDataGenerator(rescale=1./255)
train_dir = '/content/cell_images/Train_Uninfected'
test_dir = '/content/cell_images/Test_Parasitized'

train_generator = datagen_train.flow_from_directory(
    train_dir,
    target_size=(Size, Size),
    batch_size=batch_size,
    class_mode='input',
    subset='training',
    seed=42)

validation_generator = datagen_train.flow_from_directory(
    train_dir,
    target_size=(Size, Size),
    batch_size=batch_size,
    class_mode='input',
    subset='validation',
    seed=42)

anomaly_generator = datagen.flow_from_directory(
    test_dir,
    target_size=(Size, Size),
    batch_size=batch_size,
    class_mode='input',
    seed=42)
# Out:
# Found 9646 images belonging to 1 classes.
# Found 4133 images belonging to 1 classes.
# Found 13779 images belonging to 1 classes.

# %%
#Define the autoencoder
tf.random.set_seed(42)

#Encoder
model = Sequential()
model.add(Conv2D(64, (3, 3), activation='relu', padding='same', input_shape=(Size, Size, 3)))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2), padding='same'))

#Decoder
model.add(Conv2D(16, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(3, (3, 3), activation='sigmoid', padding='same'))

# %%
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mse'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 64)      1792
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 32)        18464
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 16)        4624
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 16)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 16)        2320
#
#  up_sampling2d (UpSampling2D  (None, 32, 32, 16)       0
#  )
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 32)        4640
#
#  up_sampling2d_1 (UpSampling  (None, 64, 64, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 64)        18496
#
#  up_sampling2d_2 (UpSampling  (None, 128, 128, 64)     0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 128, 128, 3)       1731
#
# =================================================================
# Total params: 52,067
# Trainable params: 52,067
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Fit the model. 
history = model.fit(
        train_generator,
        steps_per_epoch= 500 // batch_size,
        epochs=100,
        validation_data=validation_generator,
        validation_steps=75 // batch_size,
        shuffle = True)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 6s 278ms/step - loss: 0.0897 - mse: 0.0897 - val_loss: 0.0772 - val_mse: 0.0772
# Epoch 2/100
# 7/7 [==============================] - 2s 213ms/step - loss: 0.0617 - mse: 0.0617 - val_loss: 0.0456 - val_mse: 0.0456
# Epoch 3/100
# 7/7 [==============================] - 2s 211ms/step - loss: 0.0362 - mse: 0.0362 - val_loss: 0.0269 - val_mse: 0.0269
# Epoch 4/100
# 7/7 [==============================] - 2s 214ms/step - loss: 0.0219 - mse: 0.0219 - val_loss: 0.0200 - val_mse: 0.0200
# Epoch 5/100
# 7/7 [==============================] - 2s 214ms/step - loss: 0.0167 - mse: 0.0167 - val_loss: 0.0158 - val_mse: 0.0158
# Epoch 6/100
# 7/7 [==============================] - 2s 221ms/step - loss: 0.0146 - mse: 0.0146 - val_loss: 0.0158 - val_mse: 0.0158
# Epoch 7/100
# 7/7 [==============================] - 2s 239ms/step - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 8/100
# 7/7 [==============================] - 2s 289ms/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0130 - val_mse: 0.0130
# Epoch 9/100
# 7/7 [==============================] - 2s 236ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0123 - val_mse: 0.0123
# Epoch 10/100
# 7/7 [==============================] - 2s 214ms/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 11/100
# 7/7 [==============================] - 2s 214ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 12/100
# 7/7 [==============================] - 2s 215ms/step - loss: 0.0101 - mse: 0.0101 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 13/100
# 7/7 [==============================] - 2s 213ms/step - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 14/100
# 7/7 [==============================] - 2s 214ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 15/100
# 7/7 [==============================] - 2s 216ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 16/100
# 7/7 [==============================] - 2s 215ms/step - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0094 - val_mse: 0.0094
# Epoch 17/100
# 7/7 [==============================] - 3s 216ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0090 - val_mse: 0.0090
# Epoch 18/100
# 7/7 [==============================] - 2s 214ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0090 - val_mse: 0.0090
# Epoch 19/100
# 7/7 [==============================] - 2s 212ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 20/100
# 7/7 [==============================] - 2s 214ms/step - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 21/100
# 7/7 [==============================] - 1s 206ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 22/100
# 7/7 [==============================] - 2s 211ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 23/100
# 7/7 [==============================] - 2s 216ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 24/100
# 7/7 [==============================] - 2s 214ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 25/100
# 7/7 [==============================] - 2s 216ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 26/100
# 7/7 [==============================] - 2s 212ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 27/100
# 7/7 [==============================] - 2s 216ms/step - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 28/100
# 7/7 [==============================] - 2s 214ms/step - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 29/100
# 7/7 [==============================] - 2s 214ms/step - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 30/100
# 7/7 [==============================] - 2s 212ms/step - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 31/100
# 7/7 [==============================] - 2s 212ms/step - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 32/100
# 7/7 [==============================] - 2s 214ms/step - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 33/100
# 7/7 [==============================] - 2s 213ms/step - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 34/100
# 7/7 [==============================] - 2s 214ms/step - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 35/100
# 7/7 [==============================] - 2s 213ms/step - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 36/100
# 7/7 [==============================] - 2s 293ms/step - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 37/100
# 7/7 [==============================] - 2s 213ms/step - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 38/100
# 7/7 [==============================] - 2s 212ms/step - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 39/100
# 7/7 [==============================] - 2s 213ms/step - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 40/100
# 7/7 [==============================] - 2s 212ms/step - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 41/100
# 7/7 [==============================] - 2s 213ms/step - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 42/100
# 7/7 [==============================] - 2s 210ms/step - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 43/100
# 7/7 [==============================] - 2s 214ms/step - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 44/100
# 7/7 [==============================] - 2s 213ms/step - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 45/100
# 7/7 [==============================] - 2s 211ms/step - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 46/100
# 7/7 [==============================] - 1s 206ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 47/100
# 7/7 [==============================] - 2s 211ms/step - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 48/100
# 7/7 [==============================] - 2s 213ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 49/100
# 7/7 [==============================] - 2s 211ms/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 50/100
# 7/7 [==============================] - 2s 215ms/step - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 51/100
# 7/7 [==============================] - 2s 213ms/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 52/100
# 7/7 [==============================] - 2s 214ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 53/100
# 7/7 [==============================] - 2s 207ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 54/100
# 7/7 [==============================] - 2s 213ms/step - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 55/100
# 7/7 [==============================] - 2s 213ms/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 56/100
# 7/7 [==============================] - 2s 213ms/step - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 57/100
# 7/7 [==============================] - 2s 213ms/step - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 58/100
# 7/7 [==============================] - 2s 214ms/step - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 59/100
# 7/7 [==============================] - 2s 214ms/step - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 60/100
# 7/7 [==============================] - 2s 214ms/step - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 61/100
# 7/7 [==============================] - 2s 212ms/step - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 62/100
# 7/7 [==============================] - 2s 214ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 63/100
# 7/7 [==============================] - 2s 214ms/step - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 64/100
# 7/7 [==============================] - 2s 214ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 65/100
# 7/7 [==============================] - 2s 213ms/step - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 66/100
# 7/7 [==============================] - 2s 213ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 67/100
# 7/7 [==============================] - 2s 214ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 68/100
# 7/7 [==============================] - 2s 215ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 69/100
# 7/7 [==============================] - 2s 213ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 70/100
# 7/7 [==============================] - 2s 212ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 71/100
# 7/7 [==============================] - 2s 212ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 72/100
# 7/7 [==============================] - 2s 216ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 73/100
# 7/7 [==============================] - 2s 212ms/step - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 74/100
# 7/7 [==============================] - 2s 233ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 75/100
# 7/7 [==============================] - 2s 211ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 76/100
# 7/7 [==============================] - 2s 212ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 77/100
# 7/7 [==============================] - 2s 215ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 78/100
# 7/7 [==============================] - 2s 215ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 79/100
# 7/7 [==============================] - 2s 215ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 80/100
# 7/7 [==============================] - 2s 213ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 81/100
# 7/7 [==============================] - 2s 215ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 82/100
# 7/7 [==============================] - 2s 214ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 83/100
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 84/100
# 7/7 [==============================] - 2s 216ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 85/100
# 7/7 [==============================] - 2s 212ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 86/100
# 7/7 [==============================] - 2s 214ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 87/100
# 7/7 [==============================] - 2s 215ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 88/100
# 7/7 [==============================] - 2s 212ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 89/100
# 7/7 [==============================] - 2s 212ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 90/100
# 7/7 [==============================] - 2s 215ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 91/100
# 7/7 [==============================] - 2s 213ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 92/100
# 7/7 [==============================] - 2s 215ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 93/100
# 7/7 [==============================] - 2s 212ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 94/100
# 7/7 [==============================] - 2s 214ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 95/100
# 7/7 [==============================] - 2s 213ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 96/100
# 7/7 [==============================] - 2s 213ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 97/100
# 7/7 [==============================] - 2s 213ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 98/100
# 7/7 [==============================] - 2s 214ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 99/100
# 7/7 [==============================] - 2s 211ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 100/100
# 7/7 [==============================] - 2s 213ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0046 - val_mse: 0.0046

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Get all batches generated by the datagen and pick a batch for prediction
#Just to test the model. 
data_batch = []  #Capture all training batches as a numpy array
img_num = 0
while img_num <= train_generator.batch_index:   #gets each generated batch of size batch_size
    data = train_generator.next()
    data_batch.append(data[0])
    img_num = img_num + 1

pred= model.predict(data_batch[0])  #Predict on the first batch of images
pred.shape, data_batch[0].shape
# Out:
# ((64, 128, 128, 3), (64, 128, 128, 3))

# %%
pred_error = data_batch[0] - pred
pred_error_min = pred_error.min(axis = (1, 2, 3)).reshape(64,1,1,1)
pred_error_max = pred_error.max(axis = (1, 2, 3)).reshape(64,1,1,1)
norm_error = (pred_error - pred_error_min)/(pred_error_max - pred_error_min)

# %%
#View few images and corresponding reconstructions
image_number = random.randint(0, pred.shape[0])
plt.figure(figsize=(12, 6))
plt.subplot(131)
plt.imshow(data_batch[0][image_number])
plt.subplot(132)
plt.imshow(pred[image_number])
plt.subplot(133)
plt.imshow(norm_error[image_number])
plt.show()

# %%
import os
model.save(os.path.join('models', 'Autoencoder_Reconstruction'))
# Out:
# INFO:tensorflow:Assets written to: models/Autoencoder_Reconstruction/assets

# %%
#Let us examine the reconstruction error between our validation data (good/normal images)
# and the anomaly images
validation_error = model.evaluate_generator(validation_generator)
anomaly_error = model.evaluate_generator(anomaly_generator)

print("Recon. error for the validation (normal) data is: ", validation_error)
print("Recon. error for the anomaly data is: ", anomaly_error)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   after removing the cwd from sys.path.
# Recon. error for the validation (normal) data is:  [0.0045648179948329926, 0.0045648179948329926]
# Recon. error for the anomaly data is:  [0.005219509359449148, 0.005219509359449148]

# %%
tf.random.set_seed(42)

model = tf.keras.models.load_model('/content/models/Autoencoder_Reconstruction')

for layer in model.layers:
    layer.trainable = False

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 64)      1792
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 32)        18464
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 16)        4624
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 16)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 16)        2320
#
#  up_sampling2d (UpSampling2D  (None, 32, 32, 16)       0
#  )
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 32)        4640
#
#  up_sampling2d_1 (UpSampling  (None, 64, 64, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 64)        18496
#
#  up_sampling2d_2 (UpSampling  (None, 128, 128, 64)     0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 128, 128, 3)       1731
#
# =================================================================
# Total params: 52,067
# Trainable params: 0
# Non-trainable params: 52,067
# _________________________________________________________________

# %%
# Get all batches generated by the datagen and pick a batch for prediction
#Just to test the model. 
data_batch = []  #Capture all training batches as a numpy array
img_num = 0
while img_num <= validation_generator.batch_index:   #gets each generated batch of size batch_size
    data = validation_generator.next()
    data_batch.append(data[0])
    img_num = img_num + 1

pred= model.predict(data_batch[0])  #Predict on the first batch of images
pred.shape, data_batch[0].shape
# Out:
# ((64, 128, 128, 3), (64, 128, 128, 3))

# %%
pred_error = data_batch[0] - pred
pred_error_min = pred_error.min(axis = (1, 2, 3)).reshape(64,1,1,1)
pred_error_max = pred_error.max(axis = (1, 2, 3)).reshape(64,1,1,1)
norm_error = (pred_error - pred_error_min)/(pred_error_max - pred_error_min)

# %%
#View few images and corresponding reconstructions
image_number = random.randint(0, pred.shape[0])
plt.figure(figsize=(12, 6))
plt.subplot(131)
plt.imshow(data_batch[0][image_number])
plt.subplot(132)
plt.imshow(pred[image_number])
plt.subplot(133)
plt.imshow(norm_error[image_number])
plt.show()

# %%
# Get all batches generated by the datagen and pick a batch for prediction
#Just to test the model. 
data_batch = []  #Capture all training batches as a numpy array
img_num = 0
while img_num <= anomaly_generator.batch_index:   #gets each generated batch of size batch_size
    data = anomaly_generator.next()
    data_batch.append(data[0])
    img_num = img_num + 1

pred= model.predict(data_batch[0])  #Predict on the first batch of images
pred.shape, data_batch[0].shape
# Out:
# ((64, 128, 128, 3), (64, 128, 128, 3))

# %%
pred_error = data_batch[0] - pred
pred_error_min = pred_error.min(axis = (1, 2, 3)).reshape(64,1,1,1)
pred_error_max = pred_error.max(axis = (1, 2, 3)).reshape(64,1,1,1)
norm_error = (pred_error - pred_error_min)/(pred_error_max - pred_error_min)

# %%
#View few images and corresponding reconstructions
image_number = random.randint(0, pred.shape[0])
plt.figure(figsize=(12, 6))
plt.subplot(131)
plt.imshow(data_batch[0][image_number])
plt.subplot(132)
plt.imshow(pred[image_number])
plt.subplot(133)
plt.imshow(norm_error[image_number])
plt.show()
